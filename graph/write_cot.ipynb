# %%
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 
from send_data import send_data_to_gremlin, g
from parsewebcites.parsers_cot import get_cot_data
from gremlin_python.process.traversal import T

# %%
df = get_cot_data()
print(df)
# Out:
# [{'name': 'Positions', 'open interest': '7,515', 'Dealer long': '252', 'Dealer short': '110', 'Dealer spreading': '32', 'Institutional long': '695', 'Institutional short': '311', 'Institutional spreading': '9', 'Leveraged long': '2,016', 'Leveraged short': '5,302', 'Leveraged spreading': '591', 'Other long': '1,864', 'Other short': '247', 'Other spreading': '133'}, {'name': 'Changes', 'open interest': '152', 'Dealer long': '-36', 'Dealer short': '58', 'Dealer spreading': '-60', 'Institutional long': '23', 'Institutional short': '0', 'Institutional spreading': '0', 'Leveraged long': '-276', 'Leveraged short': '-240', 'Leveraged spreading': '392', 'Other long': '19', 'Other short': '8', 'Other spreading': '30', 'Nonreportable long': '60', 'Nonreportable short': '-36'}, {'name': 'Open Interest', 'open interest': 'Trader', 'Dealer long': '3.4', 'Dealer short': '1.5', 'Dealer spreading': '0.4', 'Institutional long': '9.2', 'Institutional short': '4.1', 'Institutional spreading': '0.1', 'L
# ...

# %%
send_data_to_gremlin(df)
# Out:
# '200'

# %%
g.V().groupCount().by(T.label).toList()
# Out:
# [{'gs_XLM': 4,
#   'gs_MANA': 4,
#   'gs_LINK': 4,
#   'NLP': 1,
#   'gs_FIL': 4,
#   'gs_BCH': 4,
#   'Open Interest': 3,
#   'Traders': 3,
#   'gs_BTC': 4,
#   'Changes': 3,
#   'gs_ZEC': 4,
#   'gs_BAT': 4,
#   'gs_ETC': 4,
#   'gs_ETH': 4,
#   'telegram': 1,
#   'tweet': 86220,
#   'gs_LTC': 4,
#   'Asset Manager/': 1,
#   'gs_ZEN': 4,
#   'Positions': 3,
#   'gs_LPT': 4,
#   'Leveraged': 1,
#   'cryptos': 10,
#   'Other': 1,
#   'Dealer': 1}]

# %%
open_interest = g.V().hasLabel('Open Interest').valueMap().toList()

# %%
open_interest[-1]
# Out:
# {'name': ['Open Interest'],
#  'year': [2021],
#  'month': [8],
#  'weekday': [3],
#  'day': [26],
#  'hour': [21],
#  'minute': [3],
#  'second': [29],
#  'open interest': ['Trader'],
#  'Dealer long': ['3.9'],
#  'Dealer short': ['0.7'],
#  'Dealer spreading': ['1.2'],
#  'Institutional long': ['9.1'],
#  'Institutional short': ['4.2'],
#  'Institutional spreading': ['0.1'],
#  'Leveraged long': ['31.1'],
#  'Leveraged short': ['75.3'],
#  'Leveraged spreading': ['2.7'],
#  'Other long': ['25.1'],
#  'Other short': ['3.2'],
#  'Other spreading': ['1.4'],
#  'Nonreportable long': ['25.3'],
#  'Nonreportable short': ['11.1']}
