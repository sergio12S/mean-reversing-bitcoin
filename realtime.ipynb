# %%
import requests
import pandas as pd

# %%
PARAMS = {"days": "30", "name": "ML DT"}
df = requests.get(
    "https://aipricepatterns.com/api/api/quantstrat", params=PARAMS).json()['returns']
df = pd.DataFrame(df)

# %%
df['Result'].cumsum().plot()
# Out:
# <AxesSubplot:>
