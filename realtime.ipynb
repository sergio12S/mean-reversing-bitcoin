# %%
import requests
import pandas as pd

# %%
PARAMS = {"days": "10", "name": "ML DT"}
df = requests.get(
    "https://aipricepatterns.com/api/api/quantstrat", params=PARAMS).json()['returns']
df = pd.DataFrame(df)

# %%
df['Result'].cumsum().plot()
# Out:
# <AxesSubplot:>
