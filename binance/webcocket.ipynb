# %%
from binance import ThreadedWebsocketManager
DATA = {}

# %%
twm = ThreadedWebsocketManager()
twm.start()


def handle_socket_message(msg):
    DATA = msg
    print(msg)

def our_trading_strategy(msg):
    '''do logic trading'''
    df = []
    return df

# %%
twm.start_kline_socket(callback=our_trading_strategy, symbol='BTCUSDT')
# Out:
# 'btcusdt@kline_1m'
# {'e': 'kline', 'E': 1630238247713, 's': 'BTCUSDT', 'k': {'t': 1630238220000, 'T': 1630238279999, 's': 'BTCUSDT', 'i': '1m', 'f': 1029297777, 'L': 1029297944, 'o': '48179.99000000', 'c': '48193.07000000', 'h': '48204.83000000', 'l': '48179.98000000', 'v': '9.79229000', 'n': 168, 'x': False, 'q': '471924.23564440', 'V': '9.09838000', 'Q': '438477.65610550', 'B': '0'}}
# {'e': 'kline', 'E': 1630238249744, 's': 'BTCUSDT', 'k': {'t': 1630238220000, 'T': 1630238279999, 's': 'BTCUSDT', 'i': '1m', 'f': 1029297777, 'L': 1029297947, 'o': '48179.99000000', 'c': '48193.07000000', 'h': '48204.83000000', 'l': '48179.98000000', 'v': '9.79841000', 'n': 171, 'x': False, 'q': '472219.17724310', 'V': '9.09941000', 'Q': '438527.29497790', 'B': '0'}}
# ...

# %%
DATA
# Out:
# {}
